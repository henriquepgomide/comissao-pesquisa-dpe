# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
from generate_department_data import combine_department_production

# %%
plt.rcParams["figure.figsize"] = (20,10)

# %%
# Read data
df_books, df_conferences, df_papers = combine_department_production()

# %% [markdown]
# # Produção de artigos científicos

# %%
df_papers['year'] = df_papers['year'].astype(int)
sns.countplot(x='year', data=df_papers, palette=sns.color_palette("pastel", 1))

# %% [markdown]
# # Produção de capítulo de livros

# %%
df_books['year'] = df_books['year'].astype(int)
sns.countplot(x='year', data=df_books, palette=sns.color_palette("pastel", 1))

# %% [markdown]
# # Produção de trabalhos para conferências

# %%
df_conferences['year'] = df_conferences['year'].astype(int)
sns.countplot(x='year', data=df_conferences, palette=sns.color_palette("pastel", 1))
